# %% [markdown]
# ## 4.9 Task

# %% [markdown]
# ### Part 1

# %% [markdown]
# # Contents
#     1. Import Libraries
#     2. Import Data
#     3. Wrangling Dataframe
#     4. Consistency Checks
#     5. Combining Dataframes
#     6. Exporting to pickle

# %% [markdown]
# #### 1. Import Libraries

# %%
#importing libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 2. Import Data

# %%
# establishing a path

path = r'/Users/vickyczada/Library/CloudStorage/OneDrive-Personal/Documents/Career Foundry/Data Immersion/05-2025 Instacart Basket Analysis'

# %%
# importing customers dataframe

df_cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# #### 3. Wrangling Dataframe

# %%
df_cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_cust.shape
# Out:
# (206209, 10)

# %%
# renaming columns to make them clearer 

df_cust.rename(columns = {'Surnam' : 'last_name', 'STATE' : 'state', 'n_dependants' : 'number_of_dependents', 'fam_status' : 'family_status'}, inplace = True)

# %%
# check the outcome

df_cust.head()
# Out:
#    user_id First Name last_name  Gender       state  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents family_status  income
# 0                     3       married  165665
# 1                     0        single   59285
# 2                     2       married   99568
# 3                     0        single   42049
# 4                     1       married   40374

# %% [markdown]
# #### 4. Consistency Checks

# %%
df_cust.describe()
# Out:
#              user_id            Age  number_of_dependents         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %%
# column types

df_cust.dtypes
# Out:
# user_id                  int64
# First Name              object
# last_name               object
# Gender                  object
# state                   object
# Age                      int64
# date_joined             object
# number_of_dependents     int64
# family_status           object
# income                   int64
# dtype: object

# %%
# finding missing values 

df_cust.isnull().sum()
# Out:
# user_id                     0
# First Name              11259
# last_name                   0
# Gender                      0
# state                       0
# Age                         0
# date_joined                 0
# number_of_dependents        0
# family_status               0
# income                      0
# dtype: int64

# %%
# finding duplicate rows 

df_dups = df_cust[df_cust.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, last_name, Gender, state, Age, date_joined, number_of_dependents, family_status, income]
# Index: []

# %% [markdown]
# No duplicates found.

# %% [markdown]
# #### 5. Combining Dataframes

# %%
# importing dataframe

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_grouped.pkl'))

# %%
# check 

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...  match    price_range_loc  \
# ...

# %%
# after our discussion I agree with your point and have decided to add the column back into the dataframe

result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
# check

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...    price_range_loc  \
# ...

# %%
# combining df_cust with ords_prods_merge

df_merged = pd.merge(ords_prods_merge, df_cust, on = 'user_id', how = 'inner')

# %%
# checking merge

df_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  ...     busiest_day  First Name  \
# ...

# %%
# allow to see all columns 

pd.options.display.max_columns = None

# %%
df_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
df_merged.shape
# Out:
# (32404859, 33)

# %%
# exporting as a pickle

df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_cust_merge.pkl'))
